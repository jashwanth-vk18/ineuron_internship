# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("Birds_Strike-_final_dataset.csv")

# %%
df
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane      DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# ...          ...            ...                              ...          ...
# 25551     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25552     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25553     319680            NaN                              NaN          NaN
# 25554     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25555     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 0                B-737-400                Over 100
# 1                    MD-80                Over 100
# 2                    C-500                Over 100
# 3                B-737-400                Over 100
# 4             CL-RJ100/200                Over 100
# ...                    ...                     ...
# 25551              EMB-120                       1
# 25552                A-321                       1
# 25553               EC-135                     NaN
# 25554            B-757-200                       1
# 25555            B-737-400                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  \
# 0                                 859         Engine Shut Down
# 1                                 424                      NaN
# 2                                 261                      NaN
# 3                                 806    Precautionary Landing
# 4                                 942                      NaN
# ...                               ...                      ...
# 25551                               1                      NaN
# 25552                               1                      NaN
# 25553                               1                      NaN
# 25554                               1                      NaN
# 25555                               1                      NaN
#
#              FlightDate Effect: Indicated Damage  ...  \
# 0      23-11-2000 00:00            Caused damage  ...
# 1      25-07-2001 00:00            Caused damage  ...
# 2      14-09-2001 00:00                No damage  ...
# 3      05-09-2002 00:00                No damage  ...
# 4      23-06-2003 00:00                No damage  ...
# ...                 ...                      ...  ...
# 25551  30-12-2011 00:00                No damage  ...
# 25552  30-12-2011 00:00                No damage  ...
# 25553               NaN                No damage  ...
# 25554  31-12-2011 00:00                No damage  ...
# 25555  31-12-2011 00:00            Caused damage  ...
#
#       Remains of wildlife collected? Remains of wildlife sent to Smithsonian  \
# 0                              False                                   False
# 1                              False                                   False
# 2                              False                                   False
# 3                               True                                   False
# 4                              False                                   False
# ...                              ...                                     ...
# 25551                          False                                   False
# 25552                          False                                   False
# 25553                          False                                   False
# 25554                          False                                   False
# 25555                           True                                   False
#
#       Wildlife: Size Conditions: Sky      Wildlife: Species  \
# 0             Medium        No Cloud  Unknown bird - medium
# 1              Small      Some Cloud            Rock pigeon
# 2              Small        No Cloud      European starling
# 3              Small      Some Cloud      European starling
# 4              Small        No Cloud      European starling
# ...              ...             ...                    ...
# 25551          Large        Overcast   Unknown bird - large
# 25552          Small      Some Cloud           Tree swallow
# 25553            NaN        No Cloud   Unknown bird - small
# 25554         Medium      Some Cloud  Unknown bird - medium
# 25555         Medium        No Cloud        Red-tailed hawk
#
#        Pilot warned of birds or wildlife?  Cost: Total $ Feet above ground  \
# 0                                       N         30,736             1,500
# 1                                       Y              0                 0
# 2                                       N              0                50
# 3                                       Y              0                50
# 4                                       N              0                50
# ...                                   ...            ...               ...
# 25551                                   N              0             1,500
# 25552                                   Y              0                 0
# 25553                                 NaN              0               NaN
# 25554                                   Y              0                 0
# 25555                                   N              0                 0
#
#       Number of people injured Is Aircraft Large?
# 0                            0                Yes
# 1                            0                 No
# 2                            0                 No
# 3                            0                Yes
# 4                            0                 No
# ...                        ...                ...
# 25551                        0                 No
# 25552                        0                 No
# 25553                        0                NaN
# 25554                        0                Yes
# 25555                        0                Yes
#
# [25556 rows x 25 columns]

# %%
df.shape
# Out:
# (25556, 25)

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  Number of people injured
# count   25556.000000                    25556.000000              25556.000000
# mean   253919.957740                        2.691658                  0.001057
# std     38509.468604                       12.794467                  0.050422
# min      1195.000000                        1.000000                  0.000000
# 25%    225794.250000                        1.000000                  0.000000
# 50%    248756.000000                        1.000000                  0.000000
# 75%    269170.500000                        1.000000                  0.000000
# max    321909.000000                      942.000000                  6.000000

# %%
df.isnull().sum()
# Out:
# Record ID                                      0
# Aircraft: Type                               127
# Airport: Name                                127
# Altitude bin                                 127
# Aircraft: Make/Model                           0
# Wildlife: Number struck                      127
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   23478
# FlightDate                                   127
# Effect: Indicated Damage                       0
# Aircraft: Number of engines?                 267
# Aircraft: Airline/Operator                   127
# Origin State                                 449
# When: Phase of flight                        127
# Conditions: Precipitation                  23541
# Remains of wildlife collected?                 0
# Remains of wildlife sent to Smithsonian        0
# Wildlife: Size                               127
# Conditions: Sky                                0
# Wildlife: Species                              0
# Pilot warned of birds or wildlife?           127
# Cost: Total $                                  0
# Feet above ground                            127
# Number of people injured                       0
# Is Aircraft Large?                           127
# dtype: int64

# %%
df['Origin State'].unique()
# Out:
# array(['New York', 'Texas', 'Louisiana', 'Washington', 'Virginia', nan,
#        'Delaware', 'DC', 'Georgia', 'Florida', 'California', 'Illinois',
#        'Connecticut', 'Missouri', 'Rhode Island', 'Hawaii', 'Arizona',
#        'Tennessee', 'South Carolina', 'South Dakota', 'New Jersey',
#        'Colorado', 'Minnesota', 'Alabama', 'Ohio', 'Wisconsin',
#        'Michigan', 'Massachusetts', 'Alaska', 'North Carolina',
#        'Kentucky', 'Indiana', 'Oregon', 'Pennsylvania', 'New Hampshire',
#        'Arkansas', 'Nevada', 'Mississippi', 'Maryland', 'Maine', 'Quebec',
#        'Idaho', 'British Columbia', 'Utah', 'Nebraska', 'Iowa',
#        'New Mexico', 'West Virginia', 'Oklahoma', 'North Dakota',
#        'Vermont', 'Wyoming', 'Kansas', 'Prince Edward Island', 'Montana',
#        'Puerto Rico', 'Ontario', 'Virgin Islands',
#        'Newfoundland and Labrador', 'Alberta', 'Saskatchewan'],
#       dtype=object)

# %%
df['When: Phase of flight'].unique()
# Out:
# array(['Climb', 'Landing Roll', 'Approach', 'Take-off run', 'Descent',
#        nan, 'Taxi', 'Parked'], dtype=object)

# %%
df['Aircraft: Type'].unique()
# Out:
# array(['Airplane', nan], dtype=object)

# %%
df.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?'],
#       dtype='object')

# %%
df.size
# Out:
# 638900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25556 entries, 0 to 25555
# Data columns (total 25 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25556 non-null  int64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25556 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25556 non-null  int64
#  7   Effect: Impact to flight                 2078 non-null   object
#  8   FlightDate                               25429 non-null  object
#  9   Effect: Indicated Damage                 25556 non-null  object
#  10  Aircraft: Number of engines?             25289 non-null  object
#  11  Aircraft: Airline/Operator               25429 non-null  object
#  12  Origin State                             25107 non-null  object
#  13  When: Phase of flight                    25429 non-null  object
#  14  Conditions: Precipitation                2015 non-null   object
#  15  Remains of wildlife collected?           25556 non-null  bool
#  16  Remains of wildlife sent to Smithsonian  25556 non-null  bool
#  17  Wildlife: Size                           25429 non-null  object
#  18  Conditions: Sky                          25556 non-null  object
#  19  Wildlife: Species                        25556 non-null  object
#  20  Pilot warned of birds or wildlife?       25429 non-null  object
#  21  Cost: Total $                            25556 non-null  object
#  22  Feet above ground                        25429 non-null  object
#  23  Number of people injured                 25556 non-null  int64
#  24  Is Aircraft Large?                       25429 non-null  object
# dtypes: bool(2), int64(3), object(20)
# memory usage: 4.5+ MB

# %%
df1 = df.copy()

# %%
df1
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane      DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# ...          ...            ...                              ...          ...
# 25551     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25552     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25553     319680            NaN                              NaN          NaN
# 25554     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25555     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 0                B-737-400                Over 100
# 1                    MD-80                Over 100
# 2                    C-500                Over 100
# 3                B-737-400                Over 100
# 4             CL-RJ100/200                Over 100
# ...                    ...                     ...
# 25551              EMB-120                       1
# 25552                A-321                       1
# 25553               EC-135                     NaN
# 25554            B-757-200                       1
# 25555            B-737-400                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  \
# 0                                 859         Engine Shut Down
# 1                                 424                      NaN
# 2                                 261                      NaN
# 3                                 806    Precautionary Landing
# 4                                 942                      NaN
# ...                               ...                      ...
# 25551                               1                      NaN
# 25552                               1                      NaN
# 25553                               1                      NaN
# 25554                               1                      NaN
# 25555                               1                      NaN
#
#              FlightDate Effect: Indicated Damage  ...  \
# 0      23-11-2000 00:00            Caused damage  ...
# 1      25-07-2001 00:00            Caused damage  ...
# 2      14-09-2001 00:00                No damage  ...
# 3      05-09-2002 00:00                No damage  ...
# 4      23-06-2003 00:00                No damage  ...
# ...                 ...                      ...  ...
# 25551  30-12-2011 00:00                No damage  ...
# 25552  30-12-2011 00:00                No damage  ...
# 25553               NaN                No damage  ...
# 25554  31-12-2011 00:00                No damage  ...
# 25555  31-12-2011 00:00            Caused damage  ...
#
#       Remains of wildlife collected? Remains of wildlife sent to Smithsonian  \
# 0                              False                                   False
# 1                              False                                   False
# 2                              False                                   False
# 3                               True                                   False
# 4                              False                                   False
# ...                              ...                                     ...
# 25551                          False                                   False
# 25552                          False                                   False
# 25553                          False                                   False
# 25554                          False                                   False
# 25555                           True                                   False
#
#       Wildlife: Size Conditions: Sky      Wildlife: Species  \
# 0             Medium        No Cloud  Unknown bird - medium
# 1              Small      Some Cloud            Rock pigeon
# 2              Small        No Cloud      European starling
# 3              Small      Some Cloud      European starling
# 4              Small        No Cloud      European starling
# ...              ...             ...                    ...
# 25551          Large        Overcast   Unknown bird - large
# 25552          Small      Some Cloud           Tree swallow
# 25553            NaN        No Cloud   Unknown bird - small
# 25554         Medium      Some Cloud  Unknown bird - medium
# 25555         Medium        No Cloud        Red-tailed hawk
#
#        Pilot warned of birds or wildlife?  Cost: Total $ Feet above ground  \
# 0                                       N         30,736             1,500
# 1                                       Y              0                 0
# 2                                       N              0                50
# 3                                       Y              0                50
# 4                                       N              0                50
# ...                                   ...            ...               ...
# 25551                                   N              0             1,500
# 25552                                   Y              0                 0
# 25553                                 NaN              0               NaN
# 25554                                   Y              0                 0
# 25555                                   N              0                 0
#
#       Number of people injured Is Aircraft Large?
# 0                            0                Yes
# 1                            0                 No
# 2                            0                 No
# 3                            0                Yes
# 4                            0                 No
# ...                        ...                ...
# 25551                        0                 No
# 25552                        0                 No
# 25553                        0                NaN
# 25554                        0                Yes
# 25555                        0                Yes
#
# [25556 rows x 25 columns]

# %%
df1.dropna(subset=['Aircraft: Type','Airport: Name', 'Altitude bin','Wildlife: Number struck','Effect: Impact to flight','FlightDate','Aircraft: Number of engines?','Aircraft: Airline/Operator','Origin State','When: Phase of flight','Wildlife: Size','Pilot warned of birds or wildlife?','Feet above ground','Is Aircraft Large?'],inplace=True)

# %%
df1.isnull().sum()
# Out:
# Record ID                                     0
# Aircraft: Type                                0
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                  0
# Aircraft: Airline/Operator                    0
# Origin State                                  0
# When: Phase of flight                         0
# Conditions: Precipitation                  1808
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# Cost: Total $                                 0
# Feet above ground                             0
# Number of people injured                      0
# Is Aircraft Large?                            0
# dtype: int64

# %%
df1.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  Number of people injured
# count    1995.000000                     1995.000000               1995.000000
# mean   248514.085714                        6.016541                  0.010025
# std     34349.015175                       30.550766                  0.167283
# min    200058.000000                        1.000000                  0.000000
# 25%    221356.500000                        1.000000                  0.000000
# 50%    242265.000000                        1.000000                  0.000000
# 75%    263918.000000                        4.000000                  0.000000
# max    321172.000000                      859.000000                  6.000000

# %%
df1.isnull().sum()
# Out:
# Record ID                                     0
# Aircraft: Type                                0
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                  0
# Aircraft: Airline/Operator                    0
# Origin State                                  0
# When: Phase of flight                         0
# Conditions: Precipitation                  1808
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# Cost: Total $                                 0
# Feet above ground                             0
# Number of people injured                      0
# Is Aircraft Large?                            0
# dtype: int64

# %%
df1
# Out:
#        Record ID Aircraft: Type                   Airport: Name Altitude bin  \
# 0         202152       Airplane                    LAGUARDIA NY    > 1000 ft
# 3         215953       Airplane             SEATTLE-TACOMA INTL    < 1000 ft
# 6         221697       Airplane               NEW CASTLE COUNTY    < 1000 ft
# 7         236635       Airplane     WASHINGTON DULLES INTL ARPT    < 1000 ft
# 8         207369       Airplane                    ATLANTA INTL    < 1000 ft
# ...          ...            ...                             ...          ...
# 25483     319903       Airplane                PUNTA GORDA ARPT    < 1000 ft
# 25505     319548       Airplane                 SACRAMENTO INTL    > 1000 ft
# 25515     319962       Airplane             SALT LAKE CITY INTL    < 1000 ft
# 25525     319579       Airplane         SAN FRANCISCO INTL ARPT    < 1000 ft
# 25526     319582       Airplane  FORT LAUDERDALE/HOLLYWOOD INTL    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 0                B-737-400                Over 100
# 3                B-737-400                Over 100
# 6               LEARJET-25                Over 100
# 7                    A-320                Over 100
# 8                  DC-9-30                 2 to 10
# ...                    ...                     ...
# 25483            B-737-400                       1
# 25505            B-737-700                       1
# 25515                A-320                       1
# 25525         CL-RJ100/200                       1
# 25526            B-737-700                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  \
# 0                                 859         Engine Shut Down
# 3                                 806    Precautionary Landing
# 6                                 227                    Other
# 7                                 320                    Other
# 8                                   9         Aborted Take-off
# ...                               ...                      ...
# 25483                               1         Engine Shut Down
# 25505                               1                    Other
# 25515                               1         Aborted Take-off
# 25525                               1         Aborted Take-off
# 25526                               1         Engine Shut Down
#
#              FlightDate Effect: Indicated Damage  ...  \
# 0      23-11-2000 00:00            Caused damage  ...
# 3      05-09-2002 00:00                No damage  ...
# 6      17-08-2003 00:00            Caused damage  ...
# 7      01-03-2006 00:00            Caused damage  ...
# 8      06-01-2000 00:00                No damage  ...
# ...                 ...                      ...  ...
# 25483  03-12-2011 00:00            Caused damage  ...
# 25505  08-12-2011 00:00            Caused damage  ...
# 25515  14-12-2011 00:00                No damage  ...
# 25525  17-12-2011 00:00            Caused damage  ...
# 25526  18-12-2011 00:00                No damage  ...
#
#       Remains of wildlife collected? Remains of wildlife sent to Smithsonian  \
# 0                              False                                   False
# 3                               True                                   False
# 6                               True                                    True
# 7                               True                                   False
# 8                              False                                   False
# ...                              ...                                     ...
# 25483                           True                                   False
# 25505                           True                                    True
# 25515                           True                                   False
# 25525                           True                                    True
# 25526                          False                                   False
#
#       Wildlife: Size Conditions: Sky            Wildlife: Species  \
# 0             Medium        No Cloud        Unknown bird - medium
# 3              Small      Some Cloud            European starling
# 6              Small        No Cloud            European starling
# 7              Small      Some Cloud            European starling
# 8              Small      Some Cloud                  Rock pigeon
# ...              ...             ...                          ...
# 25483          Large      Some Cloud               Sandhill crane
# 25505          Large        No Cloud  Greater white-fronted goose
# 25515         Medium        Overcast            Rough-legged hawk
# 25525         Medium        No Cloud              Red-tailed hawk
# 25526         Medium      Some Cloud                       Egrets
#
#        Pilot warned of birds or wildlife?  Cost: Total $ Feet above ground  \
# 0                                       N         30,736             1,500
# 3                                       Y              0                50
# 6                                       N      14,81,711               150
# 7                                       Y      14,83,141               100
# 8                                       N              0                 0
# ...                                   ...            ...               ...
# 25483                                   N              0                 0
# 25505                                   Y              0             2,200
# 25515                                   Y              0                 0
# 25525                                   N              0                 0
# 25526                                   Y              0                 0
#
#       Number of people injured Is Aircraft Large?
# 0                            0                Yes
# 3                            0                Yes
# 6                            0                 No
# 7                            0                 No
# 8                            0                 No
# ...                        ...                ...
# 25483                        0                Yes
# 25505                        0                Yes
# 25515                        0                 No
# 25525                        0                 No
# 25526                        0                Yes
#
# [1995 rows x 25 columns]

# %%
df1.to_csv(r'C:\Users\jashw\bird_strike_cleaned_data.xlsx',index = False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\jashw
